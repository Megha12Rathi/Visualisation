# %%
import pandas as pd   #. importing libraries

# %%
d1 = pd.read_csv('WHO-COVID-19-global-table-data.csv')  #. read the datasets
d2 = pd.read_csv('WHO-COVID-19-global-data.csv')
d3 = pd.read_csv('vaccination-data.csv')

d4 = pd.read_csv('vaccination-metadata.csv')

# %%
d1
# Out:
#                                       Name       WHO Region  \
# 0                                   Global              NaN
# 1                 United States of America         Americas
# 2                                    China  Western Pacific
# 3                                    India  South-East Asia
# 4                                   France           Europe
# ..                                     ...              ...
# 233                               Holy See           Europe
# 234                                Tokelau  Western Pacific
# 235                       Pitcairn Islands  Western Pacific
# 236  Democratic People's Republic of Korea  South-East Asia
# 237                           Turkmenistan           Europe
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                   765903278                                     9826.150648
# 1                   103343569                                    31221.372000
# ...

# %%
d1.shape  #. finding the shape of dataset
# Out:
# (238, 12)

# %%
d1.dtypes  #. finding the types of data present in dataset
# Out:
# Name                                                             object
# WHO Region                                                       object
# Cases - cumulative total                                          int64
# Cases - cumulative total per 100000 population                  float64
# Cases - newly reported in last 7 days                             int64
# Cases - newly reported in last 7 days per 100000 population     float64
# Cases - newly reported in last 24 hours                           int64
# Deaths - cumulative total                                         int64
# Deaths - cumulative total per 100000 population                 float64
# Deaths - newly reported in last 7 days                            int64
# Deaths - newly reported in last 7 days per 100000 population    float64
# Deaths - newly reported in last 24 hours                          int64
# dtype: object

# %%
d1.describe()   #. finding the description of dataset
# Out:
#        Cases - cumulative total  \
# count              2.380000e+02
# mean               6.436162e+06
# std                5.070282e+07
# min                0.000000e+00
# 25%                2.362725e+04
# 50%                1.966405e+05
# 75%                1.267148e+06
# max                7.659033e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                     20305.776188
# std                                      20033.920529
# min                                          0.000000
# 25%                                       2200.667000
# 50%                                      14026.714000
# 75%                                      33163.829000
# max                                      74420.076000
#
#        Cases - newly reported in last 7 days  \
# count                             238.000000
# mean                             3683.294118
# ...

# %%
categorical = d1.dtypes[d1.dtypes=='object'].index
print(categorical)

d1[categorical].describe()    #. decription for categorical data
# Out:
# Index(['Name', 'WHO Region'], dtype='object')
#           Name WHO Region
# count      238        237
# unique     238          7
# top     Global     Europe
# freq         1         62

# %%
d1 = d1[d1['Name'] != 'Other']  #. delete the entire row where name is other

# %%
d1.describe()
# Out:
#        Cases - cumulative total  \
# count              2.370000e+02
# mean               6.463316e+06
# std                5.080840e+07
# min                0.000000e+00
# 25%                2.421000e+04
# 50%                2.017850e+05
# 75%                1.273256e+06
# max                7.659033e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                     20305.776188
# std                                      20033.920529
# min                                          0.000000
# 25%                                       2200.667000
# 50%                                      14026.714000
# 75%                                      33163.829000
# max                                      74420.076000
#
#        Cases - newly reported in last 7 days  \
# count                             237.000000
# mean                             3698.835443
# ...

# %%
d1.isnull().sum()   #. finding the null values
# Out:
# Name                                                            0
# WHO Region                                                      1
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  0
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     0
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 0
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    0
# Deaths - newly reported in last 24 hours                        0
# dtype: int64

# %%
d1.drop(columns = ['Cases - newly reported in last 24 hours','Deaths - newly reported in last 24 hours'],inplace = True)  #. drop the columns
# Out:
# C:\Users\Megha Rathi\AppData\Local\Temp\ipykernel_25480\3968949750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d1.drop(columns = ['Cases - newly reported in last 24 hours','Deaths - newly reported in last 24 hours'],inplace = True)  #. drop the columns

# %%
d1.shape
# Out:
# (237, 10)

# %%
d1 = d1.rename(columns={'Name': 'Country'})  #. change the column name

# %%
d1.head()
# Out:
#                     Country       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 765903278
# 1  United States of America         Americas                 103343569
# 2                     China  Western Pacific                  99252425
# 3                     India  South-East Asia                  44972800
# 4                    France           Europe                  38961098
#
#    Cases - cumulative total per 100000 population  \
# 0                                     9826.150648
# 1                                    31221.372000
# 2                                     6745.960000
# 3                                     3258.888000
# 4                                    59903.878000
#
#    Cases - newly reported in last 7 days  \
# 0                                 438312
# 1                                  77165
# 2                                   3122
# 3                                  16084
# ...

# %%
d1["WHO Region"].fillna("Region", inplace = True)  #. fill the null value

# %%
d1.head()
# Out:
#                     Country       WHO Region  Cases - cumulative total  \
# 0                    Global           Region                 765903278
# 1  United States of America         Americas                 103343569
# 2                     China  Western Pacific                  99252425
# 3                     India  South-East Asia                  44972800
# 4                    France           Europe                  38961098
#
#    Cases - cumulative total per 100000 population  \
# 0                                     9826.150648
# 1                                    31221.372000
# 2                                     6745.960000
# 3                                     3258.888000
# 4                                    59903.878000
#
#    Cases - newly reported in last 7 days  \
# 0                                 438312
# 1                                  77165
# 2                                   3122
# 3                                  16084
# ...

# %%
d2.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    03-01-2020           AF  Afghanistan       EMRO          0
# 1    04-01-2020           AF  Afghanistan       EMRO          0
# 2    05-01-2020           AF  Afghanistan       EMRO          0
# 3    06-01-2020           AF  Afghanistan       EMRO          0
# 4    07-01-2020           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
d2.shape
# Out:
# (290088, 8)

# %%
d2.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.900880e+05      2.900880e+05  290088.000000       2.900880e+05
# mean   2.640245e+03      1.273095e+06      23.880264       1.677599e+04
# std    3.883344e+04      5.952495e+06     143.895654       7.172113e+04
# min   -8.261000e+03      0.000000e+00   -3520.000000       0.000000e+00
# 25%    0.000000e+00      1.589000e+03       0.000000       1.300000e+01
# 50%    1.000000e+01      3.018300e+04       0.000000       3.300000e+02
# 75%    3.430000e+02      3.447305e+05       4.000000       5.072000e+03
# max    6.966046e+06      1.033436e+08   11447.000000       1.125209e+06

# %%
categorical = d2.dtypes[d2.dtypes=='object'].index
print(categorical)

d2[categorical].describe()
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region'], dtype='object')
#        Date_reported Country_code      Country WHO_region
# count         290088       288864       290088     290088
# unique          1224          236          237          7
# top       03-01-2020           AF  Afghanistan       EURO
# freq             237         1224         1224      75888

# %%
del d2['Country_code']  #. delete the column

# %%
d2.shape  #. finding the shape of dataset
# Out:
# (290088, 7)

# %%
d2.isnull().sum()  #. finding the null values
# Out:
# Date_reported        0
# Country              0
# WHO_region           0
# New_cases            0
# Cumulative_cases     0
# New_deaths           0
# Cumulative_deaths    0
# dtype: int64

# %%
d3.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2023-05-03
# 1         Albania  ALB       EURO   REPORTING   2023-04-09
# 2         Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3  American Samoa  ASM       WPRO   REPORTING   2023-03-29
# 4         Andorra  AND       EURO   REPORTING   2023-04-09
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0          16918550.0                       14790567
# 1           3075848.0                        1347760
# 2          15267442.0                        7840131
# 3            114706.0                          46206
# 4            157038.0                          57910
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     43.461                                37.994
# 1                    106.900                                47.357
# 2                     34.817                                17.879
# ...

# %%
d3.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       1
# PERSONS_VACCINATED_1PLUS_DOSE            0
# TOTAL_VACCINATIONS_PER100                2
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     0
# PERSONS_FULLY_VACCINATED                 0
# PERSONS_FULLY_VACCINATED_PER100          0
# VACCINES_USED                            4
# FIRST_VACCINE_DATE                      22
# NUMBER_VACCINES_TYPES_USED               4
# PERSONS_BOOSTER_ADD_DOSE                18
# PERSONS_BOOSTER_ADD_DOSE_PER100         18
# dtype: int64

# %%
 d3["TOTAL_VACCINATIONS"].fillna(d3["TOTAL_VACCINATIONS"].mean(),inplace=True)   #. replace the null value by mean

# %%
 d3["TOTAL_VACCINATIONS_PER100"].fillna(d3["TOTAL_VACCINATIONS_PER100"].mode(),inplace=True)   #. replace the null value by mode

# %%
d3["VACCINES_USED"].fillna("AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...", inplace = True)  #. replace the null value by particular string

# %%
d3['NUMBER_VACCINES_TYPES_USED'].fillna(10, inplace = True)   #. replace the null value by 10

# %%
 d3["PERSONS_BOOSTER_ADD_DOSE"].fillna(d3["PERSONS_BOOSTER_ADD_DOSE"].median(),inplace=True)   #. replace the null value by median

# %%
 d3["PERSONS_BOOSTER_ADD_DOSE_PER100"].fillna(d3["PERSONS_BOOSTER_ADD_DOSE_PER100"].mean(),inplace=True)   #. replace the null value by mean

# %%
d3.drop(columns = ['FIRST_VACCINE_DATE'], axis = 1,inplace = True)   #. drop the column

# %%
d3.isnull().sum()
# Out:
# COUNTRY                                 0
# ISO3                                    0
# WHO_REGION                              0
# DATA_SOURCE                             0
# DATE_UPDATED                            0
# TOTAL_VACCINATIONS                      0
# PERSONS_VACCINATED_1PLUS_DOSE           0
# TOTAL_VACCINATIONS_PER100               0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    0
# PERSONS_FULLY_VACCINATED                0
# PERSONS_FULLY_VACCINATED_PER100         0
# VACCINES_USED                           0
# NUMBER_VACCINES_TYPES_USED              0
# PERSONS_BOOSTER_ADD_DOSE                0
# PERSONS_BOOSTER_ADD_DOSE_PER100         0
# dtype: int64

# %%
d4.head()
# Out:
#   ISO3                 VACCINE_NAME PRODUCT_NAME     COMPANY_NAME  \
# 0  GRL          Moderna - mRNA-1273    mRNA-1273          Moderna
# 1  SHN        AstraZeneca - AZD1222      AZD1222      AstraZeneca
# 2  FRO          Moderna - mRNA-1273    mRNA-1273          Moderna
# 3  FRO  Pfizer BioNTech - Comirnaty    Comirnaty  Pfizer BioNTech
# 4  BIH        AstraZeneca - AZD1222      AZD1222      AstraZeneca
#
#   AUTHORIZATION_DATE START_DATE  END_DATE  COMMENT DATA_SOURCE
# 0                NaN        NaN       NaN      NaN        OWID
# 1                NaN        NaN       NaN      NaN        OWID
# 2                NaN        NaN       NaN      NaN        OWID
# 3                NaN        NaN       NaN      NaN        OWID
# 4                NaN        NaN       NaN      NaN        OWID

# %%
d4.shape  #. find the shape of dataset
# Out:
# (1095, 9)

# %%
d4.drop(columns = ['ISO3','COMMENT','END_DATE'],inplace = True)   #. drop columns

# %%
d4.shape
# Out:
# (1095, 6)

# %%
d4['AUTHORIZATION_DATE'].fillna(method='bfill', inplace=True)   #. fill the null values by next date present date in column

# %%
d4['START_DATE'].fillna(method='bfill', inplace=True)   #. fill the null values by next date present in column

# %%
d4
# Out:
#                                            VACCINE_NAME  \
# 0                                   Moderna - mRNA-1273
# 1                                 AstraZeneca - AZD1222
# 2                                   Moderna - mRNA-1273
# 3                           Pfizer BioNTech - Comirnaty
# 4                                 AstraZeneca - AZD1222
# ...                                                 ...
# 1090  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1091  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1092  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1093  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1094  Pfizer BioNTech - Comirnaty Bivalent Original/...
#
#                                            PRODUCT_NAME     COMPANY_NAME  \
# 0                                             mRNA-1273          Moderna
# 1                                               AZD1222      AstraZeneca
# ...

# %%
d4.isnull().sum()   #. finding the null values
# Out:
# VACCINE_NAME           0
# PRODUCT_NAME           1
# COMPANY_NAME          44
# AUTHORIZATION_DATE    37
# START_DATE             0
# DATA_SOURCE            0
# dtype: int64

# %%
d4 = d4[d4['PRODUCT_NAME'].notnull()]   #. drop the entire row where the product name is null

# %%
d4 = d4.reset_index(drop=True)   #. reset the index

# %%
d4.isnull().sum()  # .checking for null values
# Out:
# VACCINE_NAME           0
# PRODUCT_NAME           0
# COMPANY_NAME          43
# AUTHORIZATION_DATE    37
# START_DATE             0
# DATA_SOURCE            0
# dtype: int64

# %%
d4 = d4[d4['COMPANY_NAME'].notnull()]  #. drop the entire row where company name is null

# %%
d4 = d4.reset_index(drop=True)  #. reset the index

# %%
d4.isnull().sum()  #. checking for null values
# Out:
# VACCINE_NAME          0
# PRODUCT_NAME          0
# COMPANY_NAME          0
# AUTHORIZATION_DATE    0
# START_DATE            0
# DATA_SOURCE           0
# dtype: int64

# %%
d4
# Out:
#                      VACCINE_NAME   PRODUCT_NAME                 COMPANY_NAME  \
# 0             Moderna - mRNA-1273      mRNA-1273                      Moderna
# 1           AstraZeneca - AZD1222        AZD1222                  AstraZeneca
# 2             Moderna - mRNA-1273      mRNA-1273                      Moderna
# 3     Pfizer BioNTech - Comirnaty      Comirnaty              Pfizer BioNTech
# 4           AstraZeneca - AZD1222        AZD1222                  AstraZeneca
# ...                           ...            ...                          ...
# 1046     Gamaleya - Sputnik-Light  Sputnik-Light  Gamaleya Research Institute
# 1047     Gamaleya - Sputnik-Light  Sputnik-Light  Gamaleya Research Institute
# 1048     Gamaleya - Sputnik-Light  Sputnik-Light  Gamaleya Research Institute
# 1049     Gamaleya - Sputnik-Light  Sputnik-Light  Gamaleya Research Institute
# 1050     Gamaleya - Sputnik-Light  Sputnik-Light  Gamaleya Research Institute
#
# ...

# %%
d1.to_csv('COVID-19-table 1-data.csv', index=False)

# %%
d2.to_csv('COVID-19-table 2-data.csv', index=False)

# %%
d3.to_csv('vaccination_1.csv', index=False)

# %%
d4.to_csv('vaccination-data.csv', index=False)
